# %%
from db_connect import get_connection
import pandas as pd

conn = get_connection()
df = pd.read_sql("SELECT TOP 10 * FROM LOV_MATERIAL", conn)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 from db_connect import get_connection
#       2 import pandas as pd
# ----> 4 conn = get_connection()
#       5 df = pd.read_sql("SELECT TOP 10 * FROM LOV_MATERIAL", conn)
#       6 df
#
# File ~/Documents/Sopra_Benchmark_18/db_connect.py:5, in get_connection()
#       4 def get_connection():
# ----> 5     with open("config.json") as f:
#       6         cfg = json.load(f)
#       8     conn_str = (
#       9         "DRIVER={ODBC Driver 18 for SQL Server};"
#      10         f"SERVER={cfg['server']};"
#    (...)
#      14         "Encrypt=no;"
#      15     )
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config.json'
