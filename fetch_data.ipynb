# %%
from db_connect import get_connection
import pandas as pd

conn = get_connection()
df = pd.read_sql("SELECT TOP 10 * FROM LOV_MATERIAL", conn)
df
# Out:
# C:\Users\marco\AppData\Local\Temp\ipykernel_21736\2295526917.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT TOP 10 * FROM LOV_MATERIAL", conn)
#    MAT_ID                                      MATERIAL_LONG
# 0       2       2 / BioBike / Mountain Bikes / Cube Aim Disc
# 1       3  3 / BioBike / Mountain Bikes / Bulls Copperhead 3
# 2       4  4 / BioBike / Mountain Bikes / Cube Reaction G...
# 3       5  5 / BioBike / Mountain Bikes / Scott Genius LT...
# 4       6          6 / BioBike / City Bikes / Corona Bravo 7
# 5       7  7 / BioBike / City Bikes / PEGASUS Avanti Wave...
# 6       8  8 / BioBike / City Bikes / Travel City EasyEnt...
# 7       9  9 / BioBike / City Bikes / Town Lite Rohloff G...
# 8      10  10 / BioBike / Kid Bikes /  Puky ZL 16-1 Alu b...
# ...
